# %%
# !pip install transformers

# %%
from transformers import pipeline

classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/mint_news_520.csv")

# %%
data['title'] = data.iloc[:, 1]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  520 non-null    int64
#  1   0           520 non-null    object
#  2   title       520 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 12.3+ KB

# %%
data = data['title']

# %%
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 520 entries, 0 to 519
# Series name: title
# Non-Null Count  Dtype
# --------------  -----
# 520 non-null    object
# dtypes: object(1)
# memory usage: 4.2+ KB

# %%
data.head()
# Out:
# 0    Punjab: 60 students fall sick after eating in ...
# 1    Earthquake today: Massive quake of 7.6 magnitu...
# 2    Israel-Hamas war 'will be long’: Israel says w...
# 3    How Satya Nadella used Virat Kohli to manage c...
# 4    Arrest of ED official sparks political row in ...
# Name: title, dtype: object

# %%
data
# Out:
# 0      Punjab: 60 students fall sick after eating in ...
# 1      Earthquake today: Massive quake of 7.6 magnitu...
# 2      Israel-Hamas war 'will be long’: Israel says w...
# 3      How Satya Nadella used Virat Kohli to manage c...
# 4      Arrest of ED official sparks political row in ...
#                              ...
# 515    ‘Ready for death penalty if..’ Baba Ramdev aft...
# 516    Army officers killed amid encounter in Kashmir...
# 517    BharatPe fraud case: Delhi Police's EOW questi...
# 518    US foils bid to kill Sikh terrorist Gurpatwant...
# 519    Bay of Bengal braces for fourth cyclonic storm...
# Name: title, Length: 520, dtype: object

# %%
data[324]
d = classifier(data[232])
d[0]['label']
# Out:
# 'POSITIVE'

# %%
lister = []
for i in range(0, 520):
  # print(classifier(data[i]))
  lister.append([i, data[i], classifier(data[i])[0]['label']])

# %%
lister
# Out:
# [[0, 'Punjab: 60 students fall sick after eating in school mess', 'NEGATIVE'],
#  [1,
#   'Earthquake today: Massive quake of 7.6 magnitude strikes Mindanao in Philippines',
#   'POSITIVE'],
#  [2,
#   "Israel-Hamas war 'will be long’: Israel says war in Gaza not 'bound by time'",
#   'NEGATIVE'],
#  [3,
#   "How Satya Nadella used Virat Kohli to manage chaos around Sam Altman's sacking",
#   'NEGATIVE'],
#  [4,
#   'Arrest of ED official sparks political row in Tamil Nadu – Details here',
#   'NEGATIVE'],
#  [5,
#   'Lt Cdr Prerna, the first woman to command Indian Naval Warship | Who is she?',
#   'NEGATIVE'],
#  [6,
#   'Ayodhya Ram Mandir: More than 6,000 invitations sent for ceremony | Watch',
#   'POSITIVE'],
#  [7,
#   'Cyclone Michaung: Depression to intensify into cyclonic storm by tomorrow',
#   'POSITIVE'],
#  [8,
#   "‘Meeting friends is…’: PM Modi as 'Melodi' selfie with Giorgia Meloni goes viral",
#   'NEGATIVE'],
#  [9,
# ...

# %%
new_data = pd.DataFrame(data = lister, columns = ['index', 'news_title', 'type'])

# %%
new_data
# Out:
#      index                                         news_title      type
# 0        0  Punjab: 60 students fall sick after eating in ...  NEGATIVE
# 1        1  Earthquake today: Massive quake of 7.6 magnitu...  POSITIVE
# 2        2  Israel-Hamas war 'will be long’: Israel says w...  NEGATIVE
# 3        3  How Satya Nadella used Virat Kohli to manage c...  NEGATIVE
# 4        4  Arrest of ED official sparks political row in ...  NEGATIVE
# ..     ...                                                ...       ...
# 515    515  ‘Ready for death penalty if..’ Baba Ramdev aft...  NEGATIVE
# 516    516  Army officers killed amid encounter in Kashmir...  NEGATIVE
# 517    517  BharatPe fraud case: Delhi Police's EOW questi...  NEGATIVE
# 518    518  US foils bid to kill Sikh terrorist Gurpatwant...  NEGATIVE
# 519    519  Bay of Bengal braces for fourth cyclonic storm...  POSITIVE
#
# [520 rows x 3 columns]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       520 non-null    int64
#  1   news_title  520 non-null    object
#  2   type        520 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 12.3+ KB

# %%
new_data.to_csv("full_mint_news.csv")
