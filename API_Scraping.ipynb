# %%
import numpy as np
import pandas as pd

# %%
import requests

url = "https://mboum-finance.p.rapidapi.com/ne/news"

headers = {
	"X-RapidAPI-Key": "d0d5b4c390msh1b9e671fe6b1ebcp1767eejsn31408039d516",
	"X-RapidAPI-Host": "mboum-finance.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'meta': {'ticker': None, 'processedTime': '2024-01-02T04:12:37.797901Z', 'version': 'v1.0', 'status': 200, 'copywrite': 'https://devAPI.ai'}, 'body': [{'title': 'Forget the "Magnificent Seven": 2024 Will Be All About the "Fab Four". Learn About Them Here.', 'link': 'https://finance.yahoo.com/news/forget-magnificent-seven-2024-fab-141500082.html', 'pubDate': '2024-01-01T14:15:00Z', 'source': 'Motley Fool', 'guid': 'forget-magnificent-seven-2024-fab-141500082.html'}, {'title': 'How an ex-police officer made $12 million in 3 years after buying ATMs for $2,100 and operating them as a side hustle', 'link': 'https://finance.yahoo.com/news/ex-police-officer-made-12-231026334.html', 'pubDate': '2024-01-01T23:10:26Z', 'source': 'Business Insider', 'guid': 'ex-police-officer-made-12-231026334.html'}, {'title': 'History Says the Nasdaq Will Surge in 2024: 2 Stock-Split Stocks to Buy Before It Does', 'link': 'https://finance.yahoo.com/news/history-says-nasdaq-surge-2024-142000237.html', 'pubDat
# ...

# %%
data = pd.DataFrame(response.json()['body', 'meta'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-aa6413fcc887> in <cell line: 1>()
# ----> 1 data = pd.DataFrame(response.json()['body', 'meta'])
#
# KeyError: ('body', 'meta')

# %%
data.head()

# %%
data.info()

# %%
for i in data.source:
  if i == 'Bloomberg':
    print("yep")

# %%
import requests

url = "https://www.livemint.com/latest-news"

r = requests.get(url).text
print(r)
# Out:
# <!DOCTYPE HTML><html lang="en"><head>
# <meta charset="utf-8"><meta name="viewport" content="width=device-width, user-scalable=yes"><meta name="referrer" content="no-referrer-when-downgrade">
# ...

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage = requests.get("https://www.livemint.com/latest-news").text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, user-scalable=yes" name="viewport"/>
#   <meta content="no-referrer-when-downgrade" name="referrer"/>
#   <link href="https://images.livemint.com" rel="preconnect"/>
#   <link href="https://www.googletagservices.com" rel="preconnect"/>
#   <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://adservice.google.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://adservice.google.co.in" rel="preconnect"/>
#   <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://ads.pubmatic.com" rel="preconnect"/>
#   <link href="https://google-analytics.com" rel="preconnect"/>
#   <link href="https://analytics.htmedia.in" rel="preconnect"/>
# ...

# %%
a = soup.find_all("h2", class_ = "headline")# a = soup.find_all("h2", id = "something")

# %%
print(a)
# Out:
# [<h2 class="headline" id="listheadline_11703473596950">
# <a href="/politics/news/yearender-2023-indian-politics-news-latest-indian-democracy-marks-milestone-with-new-parliament-samvidhan-sadan-11703473596950.html" onclick="firePromoClick('11703473596950')">
#           Year-Ender 2023: Indian democracy marks milestone with new parliament
#         </a>
# </h2>, <h2 class="headline" id="listheadline_11703483525289">
# <a href="/news/gujarat-hc-orders-probe-to-investigate-rape-human-trafficking-complaint-against-cadila-cmd-11703483525289.html" onclick="firePromoClick('11703483525289')">
#           Gujarat HC orders probe against Cadila Pharma CMD into rape allegations
#         </a>
# </h2>, <h2 class="headline" id="listheadline_11703485465814">
# <a href="/technology/apple-engages-in-talks-with-leading-news-outlets-for-ai-advancements-report-11703485465814.html" onclick="firePromoClick('11703485465814')">
# ...

# %%
for i in range(0, len(a)):
  print(a[i].text.strip())
# Out:
# Year-Ender 2023: Indian democracy marks milestone with new parliament
# Gujarat HC orders probe against Cadila Pharma CMD into rape allegations
# Apple seeks permission from major News giants for AI development: Report
# Mint Explainer: The big fuss about RBI’s AIF circular
# Beyond Bells & Baubles: 4 money lessons from Christmas movies
# These four Murugappa Group stocks have returned over 50% in CY23; do you own any?
# Year-Ender 2023: How India transitioned from defence importer to exporter
# Income Tax Return Filing 2024: 3 key changes to note in ITR Form 1 and Form 4
# Instagram, Snapchat, X or Threads; which was the most deleted app of 2023?
# Magic of compounding: Investment in this mutual fund grew 8 times in 10 years
# ‘No less than locust infestation’ netizens react to traffic congestion in Manali
# Mahindra Thar 5-door spotted testing: What to expect
# 'Market momentum may continue in 2024; FPIs will continue buying'
# ...

# %%
lister = []
for i in range(0, len(a)):
  lister.append(a[i].text.strip())

# %%
lister
# Out:
# ['Year-Ender 2023: Indian democracy marks milestone with new parliament',
#  'Gujarat HC orders probe against Cadila Pharma CMD into rape allegations',
#  'Apple seeks permission from major News giants for AI development: Report',
#  'Mint Explainer: The big fuss about RBI’s AIF circular',
#  'Beyond Bells & Baubles: 4 money lessons from Christmas movies',
#  'These four Murugappa Group stocks have returned over 50% in CY23; do you own any?',
#  'Year-Ender 2023: How India transitioned from defence importer to exporter',
#  'Income Tax Return Filing 2024: 3 key changes to note in ITR Form 1 and Form 4',
#  'Instagram, Snapchat, X or Threads; which was the most deleted app of 2023?',
#  'Magic of compounding: Investment in this mutual fund grew 8 times in 10 years',
#  '‘No less than locust infestation’ netizens react to traffic congestion in Manali',
#  'Mahindra Thar 5-door spotted testing: What to expect',
#  "'Market momentum may continue in 2024; FPIs will continue buying'",
# ...

# %%
ner = requests.get("https://www.livemint.com/news").text

# %%
soup_1 = BeautifulSoup(ner, "lxml")

# %%
print(soup_1.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="en"><head>
# <meta charset="utf-8"/><meta content="width=device-width, user-scalable=yes" name="viewport"/><meta content="no-referrer-when-downgrade" name="referrer"/>
# ...

# %%
soup_1.find_all("h2", class_ = "headline")
# Out:
# [<h2 class="headline" data-mob="Gujarat HC orders probe against Cadila Pharma CMD into rape allegations" data-reg="Gujarat HC orders probe to investigate rape, human trafficking complaint against Cadila CMD" data-title="Gujarat HC orders probe to investigate rape, human trafficking complaint against Cadila CMD" id="headline_11703483525289"><a href="https://www.livemint.com/news/gujarat-hc-orders-probe-to-investigate-rape-human-trafficking-complaint-against-cadila-cmd-11703483525289.html">Gujarat HC orders probe against Cadila Pharma CMD into rape allegations</a></h2>,
#  <h2 class="headline" data-mob="‘No less than locust infestation’ netizens react to traffic congestion in Manali" data-reg="‘&lt;i&gt;Dilli waale gaadi mei apna jaam leke chalte hain&lt;/i&gt;,’ netizens react to traffic congestion in Himachal Pradesh's Ma" data-title="‘Dilli waale gaadi mei apna jaam leke chalte hain,’ netizens react to traffic congestion in Himachal Pradesh's Ma" id="listheadline_11703480074874">
# ...

# %%
for i in soup_1.find_all('h2', class_ = 'headline'):
  print(i.text.strip())
# Out:
# Gujarat HC orders probe against Cadila Pharma CMD into rape allegations
# ‘No less than locust infestation’ netizens react to traffic congestion in Manali
# Manoj Pande to visit J-K's Rajouri to review counter-terrorist operations
# US-Canada military continues tradition of tracking Santa's location
# Fog alert! Flight operations affected in Delhi, Hyderabad due to bad weather
# Atal Bihari Vajpayee birthday: PM Modi pays floral tribute at ‘Sadaiv Atal’
# Weather Update: IMD alert very dense fog in THESE states; rains in Tamil Nadu
# Delhi's air quality remains in ‘very poor’ category; AQI stands at 387
# Turkey earthquake to Chandrayaan-3, a look at 18 biggest events of 2023
# Cold wave hits China: Beijing breaks a seven-decade cold-weather record
# 303 Indians held in France set to depart today, but destination still unknown
# Atal Bihari Vajpayee birthday: BJP to celebrate with grand events across country
# ...

# %%
dat = []
for i in soup_1.find_all('h2', class_ = 'headline'):
  dat.append(i.text.strip())

# %%
pd.DataFrame(dat)
# Out:
#                                                     0
# 0   Gujarat HC orders probe against Cadila Pharma ...
# 1   ‘No less than locust infestation’ netizens rea...
# 2   Manoj Pande to visit J-K's Rajouri to review c...
# 3   US-Canada military continues tradition of trac...
# 4   Fog alert! Flight operations affected in Delhi...
# 5   Atal Bihari Vajpayee birthday: PM Modi pays fl...
# 6   Weather Update: IMD alert very dense fog in TH...
# 7   Delhi's air quality remains in ‘very poor’ cat...
# 8   Turkey earthquake to Chandrayaan-3, a look at ...
# 9   Cold wave hits China: Beijing breaks a seven-d...
# 10  303 Indians held in France set to depart today...
# 11  Atal Bihari Vajpayee birthday: BJP to celebrat...
# 12  Israel-Hamas War: ‘We are facing monsters,’ sa...
# 13  Merry Christmas 2023: Top 20 wishes and messag...
# 14  Madhya Pradesh cabinet expansion today, confir...
# 15  Why the Houthi attacks in the Red Sea are worr...
# ...

# %%
len(soup_1.find_all('h2', class_ = 'headline'))
# Out:
# 20

# %%
import time

# %%
test = []
for i in range(1, 26):
    webpage = requests.get("https://www.livemint.com/news/page-{}".format(i)).text
    soup_1 = BeautifulSoup(webpage, 'lxml')
    for j in soup_1.find_all('h2', class_ = 'headline'):
      test.append(j.text.strip())

# %%
dat
# Out:
# ['Gujarat HC orders probe against Cadila Pharma CMD into rape allegations',
#  '‘No less than locust infestation’ netizens react to traffic congestion in Manali',
#  "Manoj Pande to visit J-K's Rajouri to review counter-terrorist operations",
#  "US-Canada military continues tradition of tracking Santa's location",
#  'Fog alert! Flight operations affected in Delhi, Hyderabad due to bad weather',
#  'Atal Bihari Vajpayee birthday: PM Modi pays floral tribute at ‘Sadaiv Atal’',
#  'Weather Update: IMD alert very dense fog in THESE states; rains in Tamil Nadu',
#  "Delhi's air quality remains in ‘very poor’ category; AQI stands at 387",
#  'Turkey earthquake to Chandrayaan-3, a look at 18 biggest events of 2023',
#  'Cold wave hits China: Beijing breaks a seven-decade cold-weather record',
#  '303 Indians held in France set to depart today, but destination still unknown',
#  'Atal Bihari Vajpayee birthday: BJP to celebrate with grand events across country',
# ...

# %%
data= dat + test

# %%
dats = pd.DataFrame(data)

# %%
dats
# Out:
#                                                      0
# 0    Gujarat HC orders probe against Cadila Pharma ...
# 1    ‘No less than locust infestation’ netizens rea...
# 2    Manoj Pande to visit J-K's Rajouri to review c...
# 3    US-Canada military continues tradition of trac...
# 4    Fog alert! Flight operations affected in Delhi...
# ..                                                 ...
# 513  Mukhtar Ansari gets over 5 years rigorous impr...
# 514  BJP MLA found guilty of raping minor girl, get...
# 515  US heralds new phase of Israel war, says not ‘...
# 516  Israel-Hamas, Russia-Ukraine, Myanmar strife: ...
# 517  Pakistan: Militants attack police HQ in Khyber...
#
# [518 rows x 1 columns]

# %%
dats.to_csv("mint_news_520.csv")

# %%
# !pip install tabula
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tabula: filename=tabula-1.0.5-py3-none-any.whl size=10586 sha256=14ede39e9a03f12c5f35352093a8b80d11f0983182c0d3b123d7780495df9f0c
#   Stored in directory: /root/.cache/pip/wheels/3c/5d/6a/bd13fe26e73e2170dfea1f6ccb69a69e824735e04b73192b39
# Successfully built tabula
# ...

# %%
import requests

url = "https://yahoo-finance127.p.rapidapi.com/historic/tsla/1d/15d"

headers = {
	"X-RapidAPI-Key": "69ecb9aaefmshdc348cfda885ac1p18b9d7jsn8a16d0072e1f",
	"X-RapidAPI-Host": "yahoo-finance127.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'meta': {'currency': 'USD', 'symbol': 'TSLA', 'exchangeName': 'NMS', 'instrumentType': 'EQUITY', 'firstTradeDate': 1277818200, 'regularMarketTime': 1710187200, 'hasPrePostMarketData': True, 'gmtoffset': -14400, 'timezone': 'EDT', 'exchangeTimezoneName': 'America/New_York', 'regularMarketPrice': 177.77, 'chartPreviousClose': 199.95, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'timezone': 'EDT', 'start': 1710230400, 'end': 1710250200, 'gmtoffset': -14400}, 'regular': {'timezone': 'EDT', 'start': 1710250200, 'end': 1710273600, 'gmtoffset': -14400}, 'post': {'timezone': 'EDT', 'start': 1710273600, 'end': 1710288000, 'gmtoffset': -14400}}, 'dataGranularity': '1d', 'range': '15d', 'validRanges': ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']}, 'timestamp': [1708439400, 1708525800, 1708612200, 1708698600, 1708957800, 1709044200, 1709130600, 1709217000, 1709303400, 1709562600, 1709649000, 1709735400, 1709821800, 1709908200, 1710163800], 'indicators': {'quote':
# ...
